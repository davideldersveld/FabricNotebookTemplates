# %%
from powerbiclient import Report, models

group_id="Workspace ID"
report_id="Report ID"

report = Report(group_id=group_id, report_id=report_id)

report
# Out:
# StatementMeta(, 8b1e8628-ef91-4009-b408-9479373b1a85, 8, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/powerbiclient/report.py:268, in Report.__init__(self, group_id, report_id, auth, view_mode, permissions, dataset_id, **kwargs)
#     267         response_key = "embedUrl"
# --> 268     embed_url = self._get_embed_url(
#     269         request_url=request_url, token=access_token, response_key=response_key)
#     271 except Exception as ex:
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/powerbiclient/report.py:309, in Report._get_embed_url(self, request_url, token, response_key)
#     308 if not response.ok:
# --> 309     raise Exception(
#     310         "Get embed URL failed with status code {0}".format(response.status_code))
#     311 return response.json()[response_key]
#
# Exception: Get embed URL failed with status code 401
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[23], line 6
#       3 group_id="Workspace ID"
#       4 report_id="Report ID"
# ----> 6 report = Report(group_id=group_id, report_id=report_id)
#       8 report
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/powerbiclient/report.py:272, in Report.__init__(self, group_id, report_id, auth, view_mode, permissions, dataset_id, **kwargs)
#     268     embed_url = self._get_embed_url(
#     269         request_url=request_url, token=access_token, response_key=response_key)
#     271 except Exception as ex:
# --> 272     raise Exception("Could not get embed URL: {0}".format(ex))
#     274 # Tells if Power BI events are being observed
#     275 self._observing_events = False
#
# Exception: Could not get embed URL: Get embed URL failed with status code 401
